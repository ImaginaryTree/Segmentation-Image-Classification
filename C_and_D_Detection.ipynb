# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import numpy as np
from keras_segmentation.models.unet import vgg_unet

# %%
original_image = "images/001b4050-36.jpg"
label_image_semantic = "labels6_color/001b4050-36.jpg"

fig, axs = plt.subplots(1, 2, figsize=(16, 8), constrained_layout=True)

axs[0].imshow( Image.open(original_image))
axs[0].grid(False)

label_image_semantic = Image.open(label_image_semantic)
label_image_semantic = np.asarray(label_image_semantic)
axs[1].imshow(label_image_semantic)
axs[1].grid(False)

# %%
# !pip install keras-segmentation
# Out:
# Collecting keras-segmentation
#   Downloading keras_segmentation-0.3.0.tar.gz (23 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Keras>=2.0.0 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from keras-segmentation) (2.7.0)
# Collecting imageio==2.5.0 (from keras-segmentation)
#   Downloading imageio-2.5.0-py3-none-any.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 4.3 MB/s eta 0:00:00
# Collecting imgaug==0.2.9 (from keras-segmentation)
#   Downloading imgaug-0.2.9-py2.py3-none-any.whl (753 kB)
#      -------------------------------------- 753.3/753.3 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from keras-segmentation) (4.8.0.74)
# Requirement already satisfied: tqdm in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from keras-segmentation) (4.65.0)
# Requirement already satisfied: numpy in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from imageio==2.5.0->keras-segmentation) (1.22.4)
# Requirement already satisfied: pillow in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from imageio==2.5.0->keras-segmentation) (10.1.0)
# Requirement already satisfied: scipy in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from imgaug==0.2.9->keras-segmentation) (1.7.3)
# Requirement already satisfied: scikit-image>=0.11.0 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from imgaug==0.2.9->keras-segmentation) (0.18.2)
# Requirement already satisfied: six in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from imgaug==0.2.9->keras-segmentation) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from imgaug==0.2.9->keras-segmentation) (3.5.0)
# Requirement already satisfied: Shapely in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from imgaug==0.2.9->keras-segmentation) (2.0.1)
# Requirement already satisfied: colorama in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from tqdm->keras-segmentation) (0.4.6)
# Requirement already satisfied: networkx>=2.0 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras-segmentation) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras-segmentation) (2021.11.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from scikit-image>=0.11.0->imgaug==0.2.9->keras-segmentation) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (4.28.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->imgaug==0.2.9->keras-segmentation) (6.3.2)
# Requirement already satisfied: setuptools in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from setuptools-scm>=4->matplotlib->imgaug==0.2.9->keras-segmentation) (59.5.0)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\asus tuf\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\asus tuf\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\asus tuf\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\asus tuf\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\asus tuf\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\asus tuf\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\asus tuf\appdata\roaming\python\python39\site-packages)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tomli>=1.0.0 in c:\users\asus tuf\appdata\local\programs\python\python39\lib\site-packages (from setuptools-scm>=4->matplotlib->imgaug==0.2.9->keras-segmentation) (1.2.2)
# Building wheels for collected packages: keras-segmentation
#   Building wheel for keras-segmentation (setup.py): started
#   Building wheel for keras-segmentation (setup.py): finished with status 'done'
#   Created wheel for keras-segmentation: filename=keras_segmentation-0.3.0-py3-none-any.whl size=29081 sha256=cbf6ff79cf962a6dfd3ff776d271780ddc48c695ef527303f4e80135511dfd21
#   Stored in directory: c:\users\asus tuf\appdata\local\pip\cache\wheels\e2\4e\8e\a401fdd0712375f53bc1be682a614957b05747535adbe8a54a
# Successfully built keras-segmentation
# Installing collected packages: imageio, imgaug, keras-segmentation
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.13.2
#     Uninstalling imageio-2.13.2:
#       Successfully uninstalled imageio-2.13.2
# Successfully installed imageio-2.5.0 imgaug-0.2.9 keras-segmentation-0.3.0

# %%
kaggle_commit = True

epochs = 20
if kaggle_commit:
    epochs = 5

# %%
n_classes = 2 # Aerial Semantic Segmentation Drone Dataset tree, gras, other vegetation, dirt, gravel, rocks, water, paved area, pool, person, dog, car, bicycle, roof, wall, fence, fence-pole, window, door, obstacle
model = vgg_unet(n_classes=n_classes ,  input_height=416, input_width=608  )

model.train( 
    train_images =  "/images/",
    train_annotations = "/labels6_color/",
    checkpoints_path = "vgg_unet" , epochs=epochs
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17556/842352073.py in <module>
#       1 n_classes = 2 # Aerial Semantic Segmentation Drone Dataset tree, gras, other vegetation, dirt, gravel, rocks, water, paved area, pool, person, dog, car, bicycle, roof, wall, fence, fence-pole, window, door, obstacle
# ----> 2 model = vgg_unet(n_classes=n_classes ,  input_height=416, input_width=608  )
#       3
#       4 model.train(
#       5     train_images =  "/images/",
#
# c:\Users\ASUS TUF\AppData\Local\Programs\Python\Python39\lib\site-packages\keras_segmentation\models\unet.py in vgg_unet(n_classes, input_height, input_width, encoder_level)
#     119 def vgg_unet(n_classes, input_height=416, input_width=608, encoder_level=3):
#     120
# --> 121     model = _unet(n_classes, get_vgg_encoder,
#     122                   input_height=input_height, input_width=input_width)
#     123     model.model_name = "vgg_unet"
#
# c:\Users\ASUS TUF\AppData\Local\Programs\Python\Python39\lib\site-packages\keras_segmentation\models\unet.py in _unet(n_classes, encoder, l1_skip_conn, input_height, input_width)
#      70           input_width=608):
#      71
# ---> 72     img_input, levels = encoder(
#      73         input_height=input_height, input_width=input_width)
#      74     [f1, f2, f3, f4, f5] = levels
#
# c:\Users\ASUS TUF\AppData\Local\Programs\Python\Python39\lib\site-packages\keras_segmentation\models\vgg16.py in get_vgg_encoder(input_height, input_width, pretrained)
#      75
#      76     if pretrained == 'imagenet':
# ---> 77         VGG_Weights_path = keras.utils.get_file(
#      78             pretrained_url.split("/")[-1], pretrained_url)
#      79         Model(img_input, x).load_weights(VGG_Weights_path)
#
# AttributeError: module 'keras.utils' has no attribute 'get_file'
